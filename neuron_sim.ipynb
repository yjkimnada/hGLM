# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.fromfile("/Users/yjkimnada/hGLM/Neuron/allDend/mixedori/vdata_NMDA_ApN0.5_13_Adend_r0_o2_i2_g_b0.bin")

# %%
print(data)
print(data.shape)
# Out:
# [ 5.09283234e-309 -7.50000000e+001 -7.50022379e+001 ... -7.14882575e+001
#  -7.14385979e+001 -7.13691044e+001]
# (240003,)

# %%
plt.figure(figsize = (10,7))
plt.plot(data[1:])

# %%
raw = open("/Users/yjkimnada/hGLM/Inputs/Ispikes_d48000_r1_rep2_Ni120_i20_I30.dat", "r")
raw_lines = raw.readlines()
bad_count = 0

with open("/Users/yjkimnada/hGLM/Neuron/allDend/mixedori/Ispikes_d48000_r1_rep2_Ni120_i20_I30.dat", "w") as clean:
    for line in raw_lines:
        if "NA" not in line:
            clean.write(line)
        else:
            bad_count += 1

raw.close()
clean.close()

print(bad_count)
# Out:
# 26

# %%
# %run -i '/Users/yjkimnada/hGLM/Neuron/mainALl.py'
# Out:
# /Users/yjkimnada/miniconda3/envs/core/lib/python3.7/site-packages/setuptools/distutils_patch.py:26: UserWarning: Distutils was imported before Setuptools. This usage is discouraged and may exhibit undesirable behaviors or errors. Please use Setuptools' objects directly or at least import Setuptools first.
#   "Distutils was imported before Setuptools. This usage is discouraged "
# 	0
# 	1
# 	1
# 	1
# 	1
# active dendrites enabled
# number of excitatory synapses: 629
# number of somatic synapses: 1
# number of inhibitory synapses: 120
# AMPA synapses added
# dExp NMDA synapses generated
# inhibitory synapses generated
# simulation type:  allDend
# dendrites are active, all branches are stimulated
# Running E bg. rate 5 I bg. rate 20 E rate 20 I rate 30 iteration: 0
# hGLM/Neuron/allDend/mixedori/Espikes_d48000_r1_rep1_Ne629_e5_E20.dat
# all of the dendrites are stimulated
# 198060 E and  544834 I spikes read from file
# plotting traces ...
# saving data ...
# ...
